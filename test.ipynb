# %%
import torch
import torch.nn.functional as F

q = torch.randn(1, 256)
b = torch.randn(3, 256)
q = F.normalize(q)
b = F.normalize(b)

# %%
s = q.mm(b.t())
sm = s.mean()
sm
# Out:
# tensor(-0.0374)

# %%
b_ = torch.mean(b, dim=0, keepdim=True)
b_ = F.normalize(b_)
q.mm(b_.t())
# Out:
# tensor([[-0.0661]])
