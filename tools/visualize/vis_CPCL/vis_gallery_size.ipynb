# %%
import numpy as np

before = np.array([91.45, 90.42, 86.31, 83.60, 80.79, 77.78]) + 91.07 - 90.42
before
# Out:
# array([92.1 , 91.07, 86.96, 84.25, 81.44, 78.43])

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['Arial']  # 如果要显示中文字体,则在此处设为：SimHei
plt.rcParams['axes.unicode_minus'] = False  # 显示负号

methods = {
        # 'HOIM': [91.4,89.7,84.7,82.3,78.7,75.1],
        # 'NAE': [92.6,91.5,87.2,84.9,82.0,78.9],
        # 'AlignPS': [94.3,93.1,89.6,87.5,84.6,81.4],
        # 'AlignPSplus': [94.7,94.0,90.8,89.1,86.8,84.0],
        # 'PSTR': [94.3,93.5,91.3,89.6,87.9,85.4],
        # 'OIM':[78.7, 75, 66, 61, 57, 52],
        'IAN':[80.1, 76, 67, 62, 59, 55],
        'RCAA':[81.3, 79.5, 71, 63, 61, 57],
        'MGTS':[83.7, 82, 77, 73.5, 70.5, 67],
        'PSTR': [94.3, 93.5, 91.3, 89.6, 87.9, 85.4],
        'CGPS':[82.55, 80.07, 72.00, 68.16, 64.18, 59.74],
        'R-Siamese':[87.1, 86.5, 79.5, 76, 73, 69],
        'SSL':[89.1, 87.4, 81.2, 78.4, 74.1, 70.1],
        # 'DICL':[88.1, 87.7, 81.2, 77.3, 74.5, 71.2],
        'Ours':[92.1, 91.07, 86.96, 84.25, 81.44, 78.43]
    }

x = [1, 2, 3, 4, 5, 6]
colors = ['b', 'g','maroon', 'c', 'm', 'y', 'k', 'r']
markers = ['o', 'v', '^', 'D', '>', 's', '*', '+']
linestyles = ['-', '-', '-', '-', '-', '--', '--', '--']

plt.figure(figsize=(10, 5), dpi=100)
plt.grid(linestyle="--")  # 设置背景网格线为虚线
for (i, name) in enumerate(methods):
    plt.plot(x, methods[name], marker=markers[i], markersize=5, color=colors[i], label=name, linewidth=2, linestyle=linestyles[i])

group_labels = [50, 100, 500, 1000, 2000, 4000]  # x轴刻度的标识
plt.xticks(x, group_labels, fontsize=12)  # 默认字体大小为10
plt.ylim((40, 100))
plt.xlabel("Gallery Size", fontsize=12)
plt.ylabel("mAP(%)", fontsize=12)

plt.legend(loc=0, prop = {'size':12})
plt.savefig('../file/gallery_size.eps', dpi=100, format='eps', bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
